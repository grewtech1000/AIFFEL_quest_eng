# %%
# !wget https://d3s0tskafalll9.cloudfront.net/media/documents/kaggle-kakr-housing-data.zip
# !unzip kaggle-kakr-housing-data.zip -d ~/work/kaggle_kakr_housing/
# Out:
# --2026-04-06 05:19:51--  https://d3s0tskafalll9.cloudfront.net/media/documents/kaggle-kakr-housing-data.zip
# Resolving d3s0tskafalll9.cloudfront.net (d3s0tskafalll9.cloudfront.net)... 3.175.207.95, 3.175.207.94, 3.175.207.115, ...
# Connecting to d3s0tskafalll9.cloudfront.net (d3s0tskafalll9.cloudfront.net)|3.175.207.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 693719 (677K) [application/zip]
# Saving to: ‘kaggle-kakr-housing-data.zip’
#
# kaggle-kakr-housing 100%[===================>] 677.46K  --.-KB/s    in 0.06s
#
# 2026-04-06 05:19:51 (11.1 MB/s) - ‘kaggle-kakr-housing-data.zip’ saved [693719/693719]
#
# Archive:  kaggle-kakr-housing-data.zip
#   inflating: /home/jovyan/work/kaggle_kakr_housing/data/sample_submission.csv
#   inflating: /home/jovyan/work/kaggle_kakr_housing/data/test.csv
#   inflating: /home/jovyan/work/kaggle_kakr_housing/data/train.csv
